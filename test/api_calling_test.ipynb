# %%
import requests

api_key = '8U4V3SZWG1XYKDJM'
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=RELIANCE.BSE&apikey={api_key}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'RELIANCE.BSE', '3. Last Refreshed': '2025-06-11', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-06-11': {'1. open': '1444.9000', '2. high': '1468.0000', '3. low': '1442.8000', '4. close': '1448.7500', '5. volume': '654096'}, '2025-06-10': {'1. open': '1448.6000', '2. high': '1453.4000', '3. low': '1436.5000', '4. close': '1438.6000', '5. volume': '481509'}, '2025-06-09': {'1. open': '1454.5500', '2. high': '1456.9000', '3. low': '1445.1000', '4. close': '1448.6000', '5. volume': '452344'}, '2025-06-06': {'1. open': '1443.6500', '2. high': '1451.3500', '3. low': '1436.7500', '4. close': '1443.5500', '5. volume': '1284697'}, '2025-06-05': {'1. open': '1426.9500', '2. high': '1454.5000', '3. low': '1423.4000', '4. close': '1442.6500', '5. volume': '427025'}, '2025-06-04': {'1. open': '1410.4000', '2. high': '1425.0000', '3. low': '1406.1500', '4. close': '1423.2000', '5. volume': '312944'}, '2025-06-03': {'1. open': '1419.8000', '2. high': '1427.0500', '3. low': '1403.0000', '4. close': '1405.9500', '5. volume': '1503679'}, '2025-06-02': {'1. open': '1415.9500', '2. high': '1417.6500', '3. low': '1395.9000', '4. close': '1414.4500', '5. volume': '469571'}, '2025-05-30': {'1. open': '1417.8000', '2. high': '1430.7500', '3. low': '1410.0000', '4. close': '1420.8000', '5. volume': '228179'}, '2025-05-29': {'1. open': '1413.3500', '2. high': '1420.1500', '3. low': '1408.9500', '4. close': '1417.4000', '5. volume': '309419'}, '2025-05-28': {'1. open': '1421.7000', '2. high': '1422.2000', '3. low': '1410.2000', '4. close': '1411.1500', '5. volume': '260943'}, '2025-05-27': {'1. open': '1429.1500', '2. high': '1437.3000', '3. low': '1414.0000', '4. close': '1421.7500', '5. volume': '1302990'}, '2025-05-26': {'1. open': '1430.4000', '2. high': '1441.2000', '3. low': '1426.0500', '4. close': '1434.1500', '5. volume': '330120'}, '2025-05-23': {'1. open': '1406.0000', '2. high': '1433.7000', '3. low': '1406.0000', '4. close': '1426.4500', '5. volume': '386757'}, '2025-05-22': {'1. open': '1420.0000', '2. high': '1422.5000', '3. low': '1397.4000', '4. close': '1409.4000', '5. volume': '388189'}, '2025-05-21': {'1. open': '1424.9500', '2. high': '1436.1000', '3. low': '1418.3500', '4. close': '1428.9000', '5. volume': '507422'}, '2025-05-20': {'1. open': '1435.6500', '2. high': '1444.5500', '3. low': '1421.2000', '4. close': '1425.3000', '5. volume': '670532'}, '2025-05-19': {'1. open': '1454.3000', '2. high': '1454.3000', '3. low': '1438.0500', '4. close': '1441.6500', '5. volume': '550729'}, '2025-05-16': {'1. open': '1453.7500', '2. high': '1460.2000', '3. low': '1447.6000', '4. close': '1456.6000', '5. volume': '338754'}, '2025-05-15': {'1. open': '1424.2500', '2. high': '1461.0000', '3. low': '1413.0000', '4. close': '1453.8000', '5. volume': '479370'}, '2025-05-14': {'1. open': '1418.1000', '2. high': '1429.8000', '3. low': '1415.5000', '4. close': '1424.2500', '5. volume': '320533'}, '2025-05-13': {'1. open': '1433.2000', '2. high': '1447.3500', '3. low': '1413.0000', '4. close': '1416.2000', '5. volume': '992150'}, '2025-05-12': {'1. open': '1400.0000', '2. high': '1438.9000', '3. low': '1400.0000', '4. close': '1436.5500', '5. volume': '792769'}, '2025-05-09': {'1. open': '1372.0500', '2. high': '1395.0000', '3. low': '1372.0500', '4. close': '1377.7500', '5. volume': '388444'}, '2025-05-08': {'1. open': '1404.9500', '2. high': '1420.5000', '3. low': '1397.0500', '4. close': '1404.8500', '5. volume': '573809'}, '2025-05-07': {'1. open': '1412.0500', '2. high': '1424.9000', '3. low': '1402.1500', '4. close': '1406.0000', '5. volume': '262093'}, '2025-05-06': {'1. open': '1432.0000', '2. high': '1432.0000', '3. low': '1410.3500', '4. close': '1420.5500', '5. volume': '311563'}, '2025-05-05': {'1. open': '1427.0000', '2. high': '1439.7500', '3. low': '1427.0000', '4. close': '1431.1000', '5. vol ...

# %%
data['Time Series (Daily)']
# Out:
# {'2025-06-11': {'1. open': '1444.9000',
#   '2. high': '1468.0000',
#   '3. low': '1442.8000',
#   '4. close': '1448.7500',
#   '5. volume': '654096'},
#  '2025-06-10': {'1. open': '1448.6000',
#   '2. high': '1453.4000',
#   '3. low': '1436.5000',
#   '4. close': '1438.6000',
#   '5. volume': '481509'},
#  '2025-06-09': {'1. open': '1454.5500',
#   '2. high': '1456.9000',
#   '3. low': '1445.1000',
#   '4. close': '1448.6000',
#   '5. volume': '452344'},
#  '2025-06-06': {'1. open': '1443.6500',
#   '2. high': '1451.3500',
#   '3. low': '1436.7500',
#   '4. close': '1443.5500',
#   '5. volume': '1284697'},
#  '2025-06-05': {'1. open': '1426.9500',
#   '2. high': '1454.5000',
#   '3. low': '1423.4000',
#   '4. close': '1442.6500',
#   '5. volume': '427025'},
#  '2025-06-04': {'1. open': '1410.4000',
#   '2. high': '1425.0000',
#   '3. low': '1406.1500',
#   '4. close': '1423.2000',
#   '5. volume': '312944'},
#  '2025-06-03': {'1. open': '1419.8000',
#   '2. high': '1427.0500',
#   '3. low': '1403.0000',
#   '4. close': '1405.9500',
#   '5. volume': '1503679'},
#  '2025-06-02': {'1. open': '1415.9500',
#   '2. high': '1417.6500',
#   '3. low': '1395.9000',
#   '4. close': '1414.4500',
#   '5. volume': '469571'},
#  '2025-05-30': {'1. open': '1417.8000',
#   '2. high': '1430.7500',
#   '3. low': '1410.0000',
#   '4. close': '1420.8000',
#   '5. volume': '228179'},
#  '2025-05-29': {'1. open': '1413.3500',
#   '2. high': '1420.1500',
#   '3. low': '1408.9500',
#   '4. close': '1417.4000',
#   '5. volume': '309419'},
#  '2025-05-28': {'1. open': '1421.7000',
#   '2. high': '1422.2000',
#   '3. low': '1410.2000',
#   '4. close': '1411.1500',
#   '5. volume': '260943'},
#  '2025-05-27': {'1. open': '1429.1500',
#   '2. high': '1437.3000',
#   '3. low': '1414.0000',
#   '4. close': '1421.7500',
#   '5. volume': '1302990'},
#  '2025-05-26': {'1. open': '1430.4000',
#   '2. high': '1441.2000',
#   '3. low': '1426.0500',
#   '4. close': '1434.1500',
#   '5. volume': '330120'},
#  '2025-05-23': {'1. open': '1406.0000',
#   '2. high': '1433.7000',
#   '3. low': '1406.0000',
#   '4. close': '1426.4500',
#   '5. volume': '386757'},
#  '2025-05-22': {'1. open': '1420.0000',
#   '2. high': '1422.5000',
#   '3. low': '1397.4000',
#   '4. close': '1409.4000',
#   '5. volume': '388189'},
#  '2025-05-21': {'1. open': '1424.9500',
#   '2. high': '1436.1000',
#   '3. low': '1418.3500',
#   '4. close': '1428.9000',
#   '5. volume': '507422'},
#  '2025-05-20': {'1. open': '1435.6500',
#   '2. high': '1444.5500',
#   '3. low': '1421.2000',
#   '4. close': '1425.3000',
#   '5. volume': '670532'},
#  '2025-05-19': {'1. open': '1454.3000',
#   '2. high': '1454.3000',
#   '3. low': '1438.0500',
#   '4. close': '1441.6500',
#   '5. volume': '550729'},
#  '2025-05-16': {'1. open': '1453.7500',
#   '2. high': '1460.2000',
#   '3. low': '1447.6000',
#   '4. close': '1456.6000',
#   '5. volume': '338754'},
#  '2025-05-15': {'1. open': '1424.2500',
#   '2. high': '1461.0000',
#   '3. low': '1413.0000',
#   '4. close': '1453.8000',
#   '5. volume': '479370'},
#  '2025-05-14': {'1. open': '1418.1000',
#   '2. high': '1429.8000',
#   '3. low': '1415.5000',
#   '4. close': '1424.2500',
#   '5. volume': '320533'},
#  '2025-05-13': {'1. open': '1433.2000',
#   '2. high': '1447.3500',
#   '3. low': '1413.0000',
#   '4. close': '1416.2000',
#   '5. volume': '992150'},
#  '2025-05-12': {'1. open': '1400.0000',
#   '2. high': '1438.9000',
#   '3. low': '1400.0000',
#   '4. close': '1436.5500',
#   '5. volume': '792769'},
#  '2025-05-09': {'1. open': '1372.0500',
#   '2. high': '1395.0000',
#   '3. low': '1372.0500',
#   '4. close': '1377.7500',
#   '5. volume': '388444'},
#  '2025-05-08': {'1. open': '1404.9500',
#   '2. high': '1420.5000',
#   '3. low': '1397.0500',
#   '4. close': '1404.8500',
#   '5. volume': '573809'},
#  '2025-05-07': {'1. open': '1412.0500',
#   '2. high': '1424.9000',
#   '3. low': '1402.1500',
#   '4. close': '1406.0000',
#   '5. volume': '262093'},
#  '2025-05-06': {'1. open': '1432.0000',
#   '2. high': '1432.0000',
#   '3. low': '1410.3500',
#   '4. close': '1420.5500',
#   '5. volume': '311563'},
#  '2025-05-05': {'1. open': '1427.0000',
#   '2. high': '1439.7500',
#   '3. low': '1427.0000',
#   '4. close': '1431.1000',
#   '5. volume': '428786'},
#  '2025-05-02': {'1. open': '1408.4000',
#   '2. high': '1426.0000',
#   '3. low': '1408.4000',
#   '4. close': '1421.9500',
#   '5. volume': '3746656'},
#  '2025-04-30': {'1. open': '1404.9000',
#   '2. high': '1411.8500',
#   '3. low': '1373.5000',
#   '4. close': '1408.3500',
#   '5. volume': '3375628'},
#  '2025-04-29': {'1. open': '1370.3500',
#   '2. high': '1410.9000',
#   '3. low': '1370.2000',
#   '4. close': '1400.3000',
#   '5. volume': '6415191'},
#  '2025-04-28': {'1. open': '1332.3500',
#   '2. high': '1374.9000',
#   '3. low': '1320.1500',
#   '4. close': '1368.5000',
#   '5. volume': '1269304'},
#  '2025-04-25': {'1. open': '1301.0000',
#   '2. high': '1325.2500',
#   '3. low': '1288.0000',
#   '4. close': '1300.0500',
#   '5. volume': '1543897'},
#  '2025-04-24': {'1. open': '1298.6500',
#   '2. high': '1304.4500',
#   '3. low': '1290.5000',
#   '4. close': '1301.6500',
#   '5. volume': '281535'},
#  '2025-04-23': {'1. open': '1295.8500',
#   '2. high': '1305.7500',
#   '3. low': '1285.3000',
#   '4. close': '1299.9000',
#   '5. volume': '420698'},
#  '2025-04-22': {'1. open': '1300.0000',
#   '2. high': '1303.0000',
#   '3. low': '1286.5000',
#   '4. close': '1290.9500',
#   '5. volume': '759456'},
#  '2025-04-21': {'1. open': '1271.5500',
#   '2. high': '1300.0000',
#   '3. low': '1266.7500',
#   '4. close': '1295.8500',
#   '5. volume': '729259'},
#  '2025-04-17': {'1. open': '1238.6500',
#   '2. high': '1279.4500',
#   '3. low': '1227.4000',
#   '4. close': '1274.5500',
#   '5. volume': '392500'},
#  '2025-04-16': {'1. open': '1239.8500',
#   '2. high': '1240.9000',
#   '3. low': '1229.0500',
#   '4. close': '1238.6500',
#   '5. volume': '361521'},
#  '2025-04-15': {'1. open': '1256.0000',
#   '2. high': '1256.0000',
#   '3. low': '1237.0000',
#   '4. close': '1239.9000',
#   '5. volume': '719043'},
#  '2025-04-11': {'1. open': '1200.0000',
#   '2. high': '1222.4500',
#   '3. low': '1197.0500',
#   '4. close': '1219.3000',
#   '5. volume': '684519'},
#  '2025-04-09': {'1. open': '1172.4000',
#   '2. high': '1189.5000',
#   '3. low': '1169.1000',
#   '4. close': '1185.6000',
#   '5. volume': '495957'},
#  '2025-04-08': {'1. open': '1177.8500',
#   '2. high': '1196.8000',
#   '3. low': '1163.8500',
#   '4. close': '1182.4000',
#   '5. volume': '894893'},
#  '2025-04-07': {'1. open': '1125.0000',
#   '2. high': '1171.0000',
#   '3. low': '1115.5500',
#   '4. close': '1166.2000',
#   '5. volume': '1433461'},
#  '2025-04-04': {'1. open': '1240.0000',
#   '2. high': '1245.2000',
#   '3. low': '1192.8500',
#   '4. close': '1204.7000',
#   '5. volume': '785059'},
#  '2025-04-03': {'1. open': '1238.9500',
#   '2. high': '1251.2000',
#   '3. low': '1234.5500',
#   '4. close': '1248.6000',
#   '5. volume': '532522'},
#  '2025-04-02': {'1. open': '1250.3500',
#   '2. high': '1256.0000',
#   '3. low': '1243.8000',
#   '4. close': '1251.1000',
#   '5. volume': '243303'},
#  '2025-04-01': {'1. open': '1274.6000',
#   '2. high': '1277.8000',
#   '3. low': '1250.0000',
#   '4. close': '1252.4500',
#   '5. volume': '722008'},
#  '2025-03-28': {'1. open': '1279.3000',
#   '2. high': '1295.7000',
#   '3. low': '1269.0500',
#   '4. close': '1275.0000',
#   '5. volume': '987799'},
#  '2025-03-27': {'1. open': '1275.0500',
#   '2. high': '1285.1500',
#   '3. low': '1272.0500',
#   '4. close': '1278.4000',
#   '5. volume': '278220'},
#  '2025-03-26': {'1. open': '1290.2500',
#   '2. high': '1293.9500',
#   '3. low': '1269.0000',
#   '4. close': '1272.5500',
#   '5. volume': '658347'},
#  '2025-03-25': {'1. open': '1307.0000',
#   '2. high': '1307.0000',
#   '3. low': '1283.0000',
#   '4. close': '1285.4000',
#   '5. volume': '865836'},
#  '2025-03-24': {'1. open': '1286.4000',
#   '2. high': '1305.3000',
#   '3. low': '1281.0000',
#   '4. close': '1301.3500',
#   '5. volume': '861533'},
#  '2025-03-21': {'1. open': '1270.0500',
#   '2. high': '1284.5000',
#   '3. low': '1270.0500',
#   '4. close': '1276.4500',
#   '5. volume': '361299'},
#  '2025-03-20': {'1. open': '1254.2000',
#   '2. high': '1272.8000',
#   '3. low': '1250.0000',
#   '4. close': '1268.5500',
#   '5. volume': '612659'},
#  '2025-03-19': {'1. open': '1242.0000',
#   '2. high': '1252.7500',
#   '3. low': '1239.3500',
#   '4. close': '1247.7000',
#   '5. volume': '295426'},
#  '2025-03-18': {'1. open': '1243.5000',
#   '2. high': '1248.1000',
#   '3. low': '1234.9000',
#   '4. close': '1238.8000',
#   '5. volume': '1740575'},
#  '2025-03-17': {'1. open': '1247.0000',
#   '2. high': '1257.2000',
#   '3. low': '1233.2500',
#   '4. close': '1240.4000',
#   '5. volume': '422823'},
#  '2025-03-13': {'1. open': '1262.9000',
#   '2. high': '1264.0000',
#   '3. low': '1244.0000',
#   '4. close': '1247.4000',
#   '5. volume': '302876'},
#  '2025-03-12': {'1. open': '1256.8500',
#   '2. high': '1261.5500',
#   '3. low': '1244.0000',
#   '4. close': '1256.6000',
#   '5. volume': '426299'},
#  '2025-03-11': {'1. open': '1238.0500',
#   '2. high': '1249.5500',
#   '3. low': '1230.0000',
#   '4. close': '1247.4000',
#   '5. volume': '305952'},
#  '2025-03-10': {'1. open': '1249.1000',
#   '2. high': '1258.0000',
#   '3. low': '1235.5000',
#   '4. close': '1238.2000',
#   '5. volume': '245117'},
#  '2025-03-07': {'1. open': '1214.0500',
#   '2. high': '1254.5000',
#   '3. low': '1212.3000',
#   '4. close': '1249.1000',
#   '5. volume': '794738'},
#  '2025-03-06': {'1. open': '1201.0000',
#   '2. high': '1214.0000',
#   '3. low': '1185.5000',
#   '4. close': '1210.5500',
#   '5. volume': '652420'},
#  '2025-03-05': {'1. open': '1162.0000',
#   '2. high': '1183.0500',
#   '3. low': '1158.0000',
#   '4. close': '1175.7500',
#   '5. volume': '348560'},
#  '2025-03-04': {'1. open': '1165.0000',
#   '2. high': '1174.1000',
#   '3. low': '1159.2500',
#   '4. close': '1161.7000',
#   '5. volume': '286826'},
#  '2025-03-03': {'1. open': '1209.8000',
#   '2. high': '1209.8000',
#   '3. low': '1156.0000',
#   '4. close': '1171.1000',
#   '5. volume': '542446'},
#  '2025-02-28': {'1. open': '1201.0000',
#   '2. high': '1217.4000',
#   '3. low': '1193.3000',
#   '4. close': '1199.6000',
#   '5. volume': '437656'},
#  '2025-02-27': {'1. open': '1213.5500',
#   '2. high': '1215.0000',
#   '3. low': '1201.0000',
#   '4. close': '1207.0500',
#   '5. volume': '193166'},
#  '2025-02-25': {'1. open': '1213.9500',
#   '2. high': '1221.0000',
#   '3. low': '1201.0000',
#   '4. close': '1203.9000',
#   '5. volume': '881729'},
#  '2025-02-24': {'1. open': '1219.4000',
#   '2. high': '1223.0000',
#   '3. low': '1210.6000',
#   '4. close': '1214.7500',
#   '5. volume': '477209'},
#  '2025-02-21': {'1. open': '1229.9500',
#   '2. high': '1239.9500',
#   '3. low': '1222.3500',
#   '4. close': '1227.7000',
#   '5. volume': '907589'},
#  '2025-02-20': {'1. open': '1226.2500',
#   '2. high': '1239.4000',
#   '3. low': '1223.0000',
#   '4. close': '1233.0500',
#   '5. volume': '206262'},
#  '2025-02-19': {'1. open': '1222.7500',
#   '2. high': '1232.8000',
#   '3. low': '1217.6000',
#   '4. close': '1226.9500',
#   '5. volume': '110206'},
#  '2025-02-18': {'1. open': '1225.2500',
#   '2. high': '1229.9500',
#   '3. low': '1216.4000',
#   '4. close': '1224.9500',
#   '5. volume': '206583'},
#  '2025-02-17': {'1. open': '1215.7500',
#   '2. high': '1227.2000',
#   '3. low': '1205.1500',
#   '4. close': '1224.7500',
#   '5. volume': '207944'},
#  '2025-02-14': {'1. open': '1220.0000',
#   '2. high': '1224.3000',
#   '3. low': '1206.0000',
#   '4. close': '1216.9500',
#   '5. volume': '358010'},
#  '2025-02-13': {'1. open': '1218.9500',
#   '2. high': '1227.9500',
#   '3. low': '1212.1500',
#   '4. close': '1216.2000',
#   '5. volume': '360188'},
#  '2025-02-12': {'1. open': '1219.9500',
#   '2. high': '1227.8500',
#   '3. low': '1193.6500',
#   '4. close': '1215.7000',
#   '5. volume': '596942'},
#  '2025-02-11': {'1. open': '1263.0500',
#   '2. high': '1263.4000',
#   '3. low': '1230.0000',
#   '4. close': '1234.6000',
#   '5. volume': '554854'},
#  '2025-02-10': {'1. open': '1263.8000',
#   '2. high': '1266.0000',
#   '3. low': '1245.8500',
#   '4. close': '1253.4000',
#   '5. volume': '539885'},
#  '2025-02-07': {'1. open': '1266.4500',
#   '2. high': '1284.7500',
#   '3. low': '1262.0000',
#   '4. close': '1266.8500',
#   '5. volume': '375026'},
#  '2025-02-06': {'1. open': '1276.6000',
#   '2. high': '1287.3500',
#   '3. low': '1270.8000',
#   '4. close': '1281.5500',
#   '5. volume': '160168'},
#  '2025-02-05': {'1. open': '1284.9500',
#   '2. high': '1290.0000',
#   '3. low': '1276.1500',
#   '4. close': '1278.0500',
#   '5. volume': '355650'},
#  '2025-02-04': {'1. open': '1247.0500',
#   '2. high': '1289.0000',
#   '3. low': '1246.6500',
#   '4. close': '1286.0000',
#   '5. volume': '397483'},
#  '2025-02-03': {'1. open': '1250.0000',
#   '2. high': '1255.9000',
#   '3. low': '1238.0000',
#   '4. close': '1245.1500',
#   '5. volume': '396687'},
#  '2025-01-31': {'1. open': '1257.4000',
#   '2. high': '1266.0000',
#   '3. low': '1249.5000',
#   '4. close': '1264.9000',
#   '5. volume': '412707'},
#  '2025-01-30': {'1. open': '1235.0000',
#   '2. high': '1256.6000',
#   '3. low': '1232.2500',
#   '4. close': '1253.6000',
#   '5. volume': '462230'},
#  '2025-01-29': {'1. open': '1237.3000',
#   '2. high': '1242.7500',
#   '3. low': '1228.4500',
#   '4. close': '1235.8000',
#   '5. volume': '358148'},
#  '2025-01-28': {'1. open': '1236.6000',
#   '2. high': '1244.1500',
#   '3. low': '1218.9000',
#   '4. close': '1233.8000',
#   '5. volume': '364260'},
#  '2025-01-27': {'1. open': '1239.9000',
#   '2. high': '1240.4500',
#   '3. low': '1220.0500',
#   '4. close': '1229.3000',
#   '5. volume': '411760'},
#  '2025-01-24': {'1. open': '1266.9000',
#   '2. high': '1273.1000',
#   '3. low': '1244.0000',
#   '4. close': '1245.9000',
#   '5. volume': '430797'},
#  '2025-01-23': {'1. open': '1274.7500',
#   '2. high': '1277.2500',
#   '3. low': '1261.5500',
#   '4. close': '1263.8500',
#   '5. volume': '235409'},
#  '2025-01-22': {'1. open': '1279.0000',
#   '2. high': '1282.9000',
#   '3. low': '1268.8000',
#   '4. close': '1277.3000',
#   '5. volume': '2201402'},
#  '2025-01-21': {'1. open': '1310.0000',
#   '2. high': '1312.8500',
#   '3. low': '1269.5500',
#   '4. close': '1272.9500',
#   '5. volume': '1210468'},
#  '2025-01-20': {'1. open': '1319.3500',
#   '2. high': '1319.3500',
#   '3. low': '1300.5500',
#   '4. close': '1305.0000',
#   '5. volume': '242236'},
#  '2025-01-17': {'1. open': '1325.1000',
#   '2. high': '1325.1000',
#   '3. low': '1284.7000',
#   '4. close': '1301.3000',
#   '5. volume': '1514067'},
#  '2025-01-16': {'1. open': '1260.2000',
#   '2. high': '1275.0000',
#   '3. low': '1251.4000',
#   '4. close': '1268.7000',
#   '5. volume': '391749'},
#  '2025-01-15': {'1. open': '1247.0000',
#   '2. high': '1256.7500',
#   '3. low': '1242.1500',
#   '4. close': '1252.3000',
#   '5. volume': '287139'},
#  '2025-01-14': {'1. open': '1240.0000',
#   '2. high': '1255.0500',
#   '3. low': '1227.3000',
#   '4. close': '1238.5500',
#   '5. volume': '837785'}}

# %%
import pandas as pd

# %%
def get_stock_data(ticker):
    api_key = '8U4V3SZWG1XYKDJM'
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={ticker}&apikey={api_key}'
    r = requests.get(url)
    data = r.json()
    
    if 'Time Series (Daily)' not in data:
        raise ValueError(f"Could not get daily time series data for {ticker}. Response: {data}")
        
    time_series = data['Time Series (Daily)']
    filtered_data = []
    
    for date in time_series:
        filtered_data.append({
            'date': date,
            'close': float(time_series[date]['4. close']),
            'volume': int(time_series[date]['5. volume'])
        })
            
    return pd.DataFrame(filtered_data).set_index('date')

# %%
get_stock_data('RELIANCE.BSE')
# Out:
#               close   volume
# date
# 2025-06-11  1448.75   654096
# 2025-06-10  1438.60   481509
# 2025-06-09  1448.60   452344
# 2025-06-06  1443.55  1284697
# 2025-06-05  1442.65   427025
# ...             ...      ...
# 2025-01-20  1305.00   242236
# 2025-01-17  1301.30  1514067
# 2025-01-16  1268.70   391749
# 2025-01-15  1252.30   287139
# 2025-01-14  1238.55   837785
#
# [100 rows x 2 columns]
